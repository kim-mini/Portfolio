# %% [markdown]
# ## 다음 기사

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://news.v.daum.net/v/20170615203441266')
print(res.content)
# Out:
# b'<!doctype html>\n<html lang="ko"> \n <head data-cloud-area="head"> \n  <meta charset="utf-8"> \n  <meta http-equiv="X-UA-Compatible" content="IE=edge"> \n  <style>\n            @import url(\'//t1.daumcdn.net/harmony_static/cloud/page/4c79e7f1899f2ca79057bcefff68f6b78a200f96.css\');\n            @import url(\'//t1.daumcdn.net/harmony_static/cloud/2020/12/02/common.ae516f46c0a95bbc9fd0.css\')\n        </style> \n  <style>\n            /* \xeb\x8b\xa4\xec\x9d\x8c \xec\xb9\xb4\xed\x8e\x98 \xec\x86\x8c\xec\x85\x9c \xec\x89\x90\xec\x96\xb4 \xec\x9e\x84\xec\x8b\x9c \xeb\xb9\x84\xed\x99\x9c\xec\x84\xb1\xed\x99\x94 */\n            .list_sns li:nth-child(6) {\n                display: none;\n            }\n        </style> \n  <meta name="robots" content="noindex"> \n  <meta property="mccp:docId" content="nkhSoinQsa"> \n  <meta property="og:site_name" content="\xeb\x8b\xa4\xec\x9d\x8c\xeb\x89\xb4\xec\x8a\xa4"> \n  <meta property="og:title" content="\xec\x9e\x94\xea\xb8\x88\xeb\x8c\x80\xec\xb
# ...

# %%
soup = BeautifulSoup(res.content, 'html.parser')

# %%
title = soup.find('title')

# %%
print(title.get_text())
# Out:
# 잔금대출에도 DTI 규제 적용 검토

# %% [markdown]
# ## 태그

# %%
html = """
<html>
    <body>
        <h1 id='title'>[1]크롤링이란?</h1>;
        <p class='cssstyle'>웹페이지에서 필요한 데이터를 추출하는 것</p>
        <p id='body' align='center'>파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>
    </body>
</html>
"""

soup = BeautifulSoup(html, 'html.parser')
title_data = soup.find('h1')
print(title_data)
# Out:
# <h1 id="title">[1]크롤링이란?</h1>

# %%
# title_data에서 html은 빼고 문자열만 추출
print(title_data.string)
print(title_data.get_text())
# Out:
# [1]크롤링이란?
# [1]크롤링이란?

# %%
paragraph_data = soup.find('p')
print(paragraph_data)
# Out:
# <p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것</p>

# %%
print(paragraph_data.string)
print(paragraph_data.get_text())
# Out:
# 웹페이지에서 필요한 데이터를 추출하는 것
# 웹페이지에서 필요한 데이터를 추출하는 것

# %%
# 태그에 있는 id로 검색
title_data = soup.find(id='title')
print(title_data)
print(title_data.string)
print(title_data.get_text())
# Out:
# <h1 id="title">[1]크롤링이란?</h1>
# [1]크롤링이란?
# [1]크롤링이란?

# %%
# HTMl 태그와 CSS class를 활용해서 필요한 데이터를 추출하는 방법1
paragraph_data = soup.find('p', class_='cssstyle')
print(paragraph_data.get_text())

# HTMl 태그와 CSS class를 활용해서 필요한 데이터를 추출하는 방법2
paragraph_data = soup.find('p','cssstyle')
print(paragraph_data.get_text())
# Out:
# 웹페이지에서 필요한 데이터를 추출하는 것
# 웹페이지에서 필요한 데이터를 추출하는 것

# %%
# HTML 태그와 태그에 있는 속성:속성값을 활용해서 필요한 데이터를 추출하는 방법
paragraph_data = soup.find('p', attrs = {'align': 'center'})
print(paragraph_data.get_text())
# Out:
# 파이썬을 중심으로 다양한 웹크롤링 기술 발달

# %%
paragraph_data = soup.find_all('p')
for i in range(len(paragraph_data)):
    print(paragraph_data[i].get_text())
# Out:
# 웹페이지에서 필요한 데이터를 추출하는 것
# 파이썬을 중심으로 다양한 웹크롤링 기술 발달

# %% [markdown]
# ## BeautifulSoup 라이브러리 활용 string 검색 예제

# %%
res = requests.get('https://news.v.daum.net/v/20170518153405933')
soup = BeautifulSoup(res.content, 'html5lib')

print(soup.find_all(string='오대석'))
print(soup.find_all(string='AI'))
# Out:
# ['오대석']
# []

# %% [markdown]
# ## 연습문제
# 다음 사이트에서 링크가 되어 있는 모든 제목을 가져와서 출력합니다.
# http://media.daum.net/digital/
#
# - 참고코드: git 저장소에서 02_examples/crawling_seeko_title.py 를 참고
# - 프로그래밍은 스스로 작성을 해야 합니다. 정 이해하기 어려울 때만 참고코드를 보시면 좋을 것 같습니다.

# %%
url = 'https://news.daum.net/digital#1'
res = requests.get(url)
print(res.content)
# Out:
# b'\n<!DOCTYPE html>\n\n\n\n<html lang="ko" class="os_unknown none unknown version_0 ">\n<head>\n<meta charset="utf-8">\n<meta name="referrer" content="always" />\n\n<meta property="og:author" content="Daum \xeb\x89\xb4\xec\x8a\xa4" />\n<meta property="og:site_name" content="\xeb\x8b\xa4\xec\x9d\x8c\xeb\x89\xb4\xec\x8a\xa4" />\n<meta property="og:title" content="IT"/>\n<meta property="og:image" content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" />\n<meta property="og:description" content="\xeb\x8b\xa4\xec\x9d\x8c\xeb\x89\xb4\xec\x8a\xa4" />\n<link rel="shortcut icon" href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">\n\n<title>IT | \xeb\x8b\xa4\xec\x9d\x8c\xeb\x89\xb4\xec\x8a\xa4</title>\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/7c90f3a/common.css.merged.css" />\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/7c90f3a/news.c
# ...

# %%
soup = BeautifulSoup(res.content,'html.parser',from_encoding='utf-8')

# %%
#n_title = soup.find_all('img')
n_title = soup.find_all('img')

for title in n_title:
    print(title.get('alt'))
# Out:
# 가상자산 거래소 빗썸 매각 급물살..'넥슨, 후오비' 물망
# 삼성 '갤럭시S21' 출고가 99만원대 유력..전작보다 25만원 저렴
# 오후 6시까지 전국서 494명 확진..전날보다 154명↓
# 8일부터 실내체육시설 9인 이하 교습 허용..17일부터 다중이용시설 허용
# 몸값 낮추는 갤럭시S21..99만9천원대 유력
# 뉴스봇 '오늘의 뉴스 브리핑'
# 가상자산 거래소 빗썸 매각 급물살..'넥슨, 후오비' 물망
# '갤럭시S21' 출고가 99만원대..가격 '승부수' 띄운 삼성
# 정부, '제2의 D램'으로 AI반도체 집중 육성한다
# 포스트코로나 시대의 기업 성장 전략, "스타트업에게 물어보자" 2부
# 삼성 '갤럭시S21' 출고가 99만원대 유력..전작보다 25만원 저렴
# ESPN 가진 디즈니, 韓스포츠 중계 흔드나
# [김대영의 무기 인사이드] 빠른 속도와 은밀성 자랑하는 차세대 '미래공격정찰헬기'
# 포스트코로나 시대의 기업 성장 전략, "스타트업에게 물어보자" 1부
# 최후의 1인을 가린다!<br>카카오 배틀그라운드
# 대체불가 핵앤슬래시! <br> 패스 오브 엑자일
